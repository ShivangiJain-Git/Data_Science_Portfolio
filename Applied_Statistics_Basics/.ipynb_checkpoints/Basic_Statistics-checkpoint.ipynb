# %% [markdown]
# # Case Study on Telecom Company using Churn dataset

# %% [markdown]
# # Context:
# Predict behavior to retain customers. Analyzing all relevant customer data and develop focused customer retention programs.
#
# Content:
# Each row represents a customer, each column contains customer’s attributes described on the column Metadata.
# The dataset contains the above information about the data.

# %% [markdown]
# ## Objective

# %% [markdown]
# To learn about Basic Statistics Concepts.

# %% [markdown]
# ## Content

# %% [markdown]
# 1. Import necessary Libraries
# 2. Displaying dataframe
# 3. About attributes
# 4. Histogram
# 5. Countplot
# 6. Heatmap
# 7. Crosstab
# 9. Distplot

# %% [markdown]
# ## Dataset:
#
# The dataset is about telecom industry which tells about the number of customers who churned the service. It consists of 3333 observations having 21 variables. We have to predict which customer is going to churn the service.
#
# Account Length: how long account has been active.
# VMail Message: Number of voice mail messages send by the customer.
#
# Day Mins: Time spent on day calls.
#
# Eve Mins: Time spent on evening calls.
#
# Night Mins: Time spent on night calls.
#
# Intl Mins: Time spent on international calls.
#
# Day Calls: Number of day calls by customers.
#
# Eve Calls: Number of evening calls by customers.
#
# Intl Calls: Number of international calls.
#
# Night Calls: Number of night calls by customer.
#
# Day Charge: Charges of Day Calls.
#
# Night Charge: Charges of Night Calls.
#
# Eve Charge: Charges of evening Calls.
#
# Intl Charge: Charges of international calls.
#
# VMail Plan: Voice mail plan taken by the customer or not.
#
# State: State in Area of study.
#
# Phone: Phone number of the customer.
#
# Area Code: Area Code of customer.
#
# Intl Plan: Does customer have international plan or not.
#
# CustServ Calls: Number of customer service calls by customer.
#
# Churn : Customers who churned the telecom service or who doesn’t(0=“Churner”, 1=“Non-Churner”)

# %% [markdown]
# ## Import necessary libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Import the data

# %%
df = pd.read_csv("Churn.csv")

# %% [markdown]
# ## How do we display the dataframe?

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## About attributes

# %%
pd.DataFrame(df.columns, columns =['Attributes'])
# Out:
#                 Attributes
# 0                    state
# 1           account length
# 2                area code
# 3             phone number
# 4       international plan
# 5          voice mail plan
# 6    number vmail messages
# 7        total day minutes
# 8          total day calls
# 9         total day charge
# 10       total eve minutes
# 11         total eve calls
# 12        total eve charge
# 13     total night minutes
# 14       total night calls
# 15      total night charge
# 16      total intl minutes
# 17        total intl calls
# 18       total intl charge
# 19  customer service calls
# 20                   churn

# %% [markdown]
# ## Calculate Histogram for time spent on day calls by customers.

# %%
plt.hist(df['total day minutes'], bins= 10, facecolor= 'tan')
plt.xlabel('Total Day Minutes')
plt.ylabel('No. of Customers')
plt.show()

# %% [markdown]
# ## Categorize the churner and the non-churner for the time spent on day calls(total day minutes)?

# %%
g = sns.FacetGrid(df, col="churn")
g.map(plt.hist, "total day minutes");

# %% [markdown]
# ## Find the number of customers who did opt for voice mail plan

# %%
df['voice mail plan'].value_counts()
# Out:
# no     2411
# yes     922
# Name: voice mail plan, dtype: int64

# %% [markdown]
# ## Plot a countplot for the above result

# %%
sns.countplot(df['voice mail plan'], hue='churn', data=df);

# %% [markdown]
# ## Creating boxplot for a categorical variable(international plan) and continuous variable(area code).

# %%
df['international plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
sns.boxplot(x = "international plan", y = "area code", data=df);

# %% [markdown]
# ## Creating crosstab for the area code to find the churner or non-churner.

# %%
df['area code'].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %%
pd.crosstab(df['area code'],df['voice mail plan'])
# Out:
# voice mail plan    no  yes
# area code
# 408               618  220
# 415              1184  471
# 510               609  231

# %% [markdown]
# ## Creating pivot information using python for categorical values? Plot one.

# %%
df['international plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
pd.pivot_table(df, index = ['area code','voice mail plan'],columns= ['international plan'], aggfunc=len)
# Out:
#                           account length      churn       \
# international plan                    no  yes    no  yes
# area code voice mail plan
# 408       no                         567   51   567   51
#           yes                        200   20   200   20
# 415       no                        1082  102  1082  102
#           yes                        423   48   423   48
# 510       no                         531   78   531   78
#           yes                        207   24   207   24
#
#                           customer service calls      number vmail messages  \
# international plan                            no  yes                    no
# area code voice mail plan
# 408       no                                 567   51                   567
#           yes                                200   20                   200
# 415       no                                1082  102                  1082
#           yes                                423   48                   423
# 510       no                                 531   78                   531
#           yes                                207   24                   207
#
#                                phone number       ... total intl charge  \
# international plan         yes           no  yes  ...                no
# area code voice mail plan                         ...
# 408       no                51          567   51  ...             567.0
#           yes               20          200   20  ...             200.0
# 415       no               102         1082  102  ...            1082.0
#           yes               48          423   48  ...             423.0
# 510       no                78          531   78  ...             531.0
#           yes               24          207   24  ...             207.0
#
#                                  total intl minutes        total night calls  \
# international plan           yes                 no    yes                no
# area code voice mail plan
# 408       no                51.0              567.0   51.0               567
#           yes               20.0              200.0   20.0               200
# 415       no               102.0             1082.0  102.0              1082
#           yes               48.0              423.0   48.0               423
# 510       no                78.0              531.0   78.0               531
#           yes               24.0              207.0   24.0               207
#
#                                total night charge        total night minutes  \
# international plan         yes                 no    yes                  no
# area code voice mail plan
# 408       no                51              567.0   51.0               567.0
#           yes               20              200.0   20.0               200.0
# 415       no               102             1082.0  102.0              1082.0
#           yes               48              423.0   48.0               423.0
# 510       no                78              531.0   78.0               531.0
#           yes               24              207.0   24.0               207.0
#
#
# international plan           yes
# area code voice mail plan
# 408       no                51.0
#           yes               20.0
# 415       no               102.0
#           yes               48.0
# 510       no                78.0
#           yes               24.0
#
# [6 rows x 36 columns]

# %% [markdown]
# ## Understanding correlation between the variables or the columns within the dataframe. Plot one and analyze.

# %%
plt.figure(figsize = (16,16))
corr = df.corr()
sns.heatmap(corr, annot = True)

# %% [markdown]
# ## Finding Standard deviation of total night calls.

# %%
df['total night calls'].std()
# Out:
# 19.568609346058615

# %% [markdown]
# ## Plotting distplot

# %%
sns.distplot(df['total night calls'])

# %% [markdown]
# ## Plot a histogram to group it by churner or non-churner for the column area code.

# %%
df.hist(by='churn', column = 'area code');

# %% [markdown]
# ## Calculate areawise churner or non-churner using countplot.

# %%
df['area code']= df['area code'].astype('category')
sns.countplot(x="area code", hue= "churn", data=df)
